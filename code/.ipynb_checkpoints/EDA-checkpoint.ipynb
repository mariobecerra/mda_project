# %%
import os
os.getcwd()
os.chdir("C:\\Users\\baris\\Desktop\\Modern Data Analytics")

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("out/merged.csv", sep = ",", index_col=0)

# %%
data.head(10)
# Out:
#    YEAR  ARRON  WEEK  population_t YEAR_WEEK  Nom_arrondissement  \
# 0  2000  11000     1      932103.0  2000-001           Antwerpen
# 1  2000  12000     1      305670.0  2000-001            Mechelen
# 2  2000  13000     1      406199.0  2000-001            Turnhout
# 3  2000  21000     1      959318.0  2000-001  Bruxelles-Capitale
# 4  2000  23000     1      558220.0  2000-001        Hal-Vilvorde
# 5  2000  24000     1      456484.0  2000-001              Leuven
# 6  2000  25000     1      349884.0  2000-001            Nivelles
# 7  2000  31000     1      270866.0  2000-001              Brugge
# 8  2000  32000     1       47992.0  2000-001           Diksmuide
# 9  2000  33000     1      104278.0  2000-001               Ypres
#
#    heatwave_week_boolean    COD_y  N_MASK
# 0                      0  natural    31.0
# 1                      0  natural    10.0
# 2                      0  natural    14.0
# 3                      0  natural    43.0
# 4                      0  natural    14.0
# 5                      0  natural    20.0
# 6                      0  natural    15.0
# 7                      0  natural    14.0
# 8                      0  natural     NaN
# 9                      0  natural     6.0

# %%
data.describe()
# Out:
#                YEAR         ARRON          WEEK  population_t  Unnamed: 0.1  \
# count  44713.000000  44713.000000  44713.000000  4.461000e+04  44713.000000
# mean    2009.493369  51187.685908     26.653546  2.524206e+05  41299.282312
# std        5.764971  22800.066144     15.010964  2.333094e+05  23383.574902
# min     2000.000000  11000.000000      1.000000  4.057400e+04      1.000000
# 25%     2004.000000  34000.000000     14.000000  8.179025e+04  21203.000000
# 50%     2009.000000  51000.000000     27.000000  1.837520e+05  41137.000000
# 75%     2014.000000  71000.000000     40.000000  3.164360e+05  61999.000000
# max     2019.000000  93000.000000     53.000000  1.217888e+06  81141.000000
#
#        heatwave_week_boolean        N_MASK
# count           44713.000000  44446.000000
# mean                0.036499     44.125343
# std                 0.187531     40.172202
# min                 0.000000      4.000000
# 25%                 0.000000     16.000000
# 50%                 0.000000     32.000000
# 75%                 0.000000     57.000000
# max                 1.000000    317.000000

# %%
data.heatwave_week_boolean.sum() /data.heatwave_week_boolean.count()
# Out:
# 0.03649945206092188

# %%
data[data['heatwave_week_boolean']==0]
# Out:
#        YEAR  ARRON  WEEK  population_t  Unnamed: 0.1 YEAR_WEEK  \
# 0      2000  11000     1      932103.0             1  2000-001
# 1      2000  12000     1      305670.0          2080  2000-001
# 2      2000  13000     1      406199.0          4105  2000-001
# 3      2000  21000     1      959318.0          6163  2000-001
# 4      2000  23000     1      558220.0          8243  2000-001
# 5      2000  24000     1      456484.0         10316  2000-001
# 6      2000  25000     1      349884.0         12379  2000-001
# 7      2000  31000     1      270866.0         14441  2000-001
# 1                 Mechelen                      0  natural    10.0
# 2                 Turnhout                      0  natural    14.0
# 3       Bruxelles-Capitale                      0  natural    43.0
# 4             Hal-Vilvorde                      0  natural    14.0
# 5                   Leuven                      0  natural    20.0
# 6                 Nivelles                      0  natural    15.0
# 7                   Brugge                      0  natural    14.0
# 8                Diksmuide                      0  natural     NaN
# 9                    Ypres                      0  natural     6.0
# 10                Courtrai                      0  natural    10.0
# 11                Oostende                      0  natural     7.0
# 12               Roeselare                      0  natural     5.0
# 13                   Tielt                      0  natural     6.0
# 14                  Veurne                      0  natural     4.0
# 15                   Aalst                      0  natural     5.0
# 16             Dendermonde                      0  natural     6.0
# 17                   Eeklo                      0  natural     4.0
# 18                    Gent                      0  natural    12.0
# 19               Audenarde                      0  natural     4.0
# 20            Sint-Niklaas                      0  natural     9.0
# 21                     Ath                      0  natural     NaN
# 22               Charleroi                      0  natural    19.0
# 23                    Mons                      0  natural     7.0
# 24                Soignies                      0  natural    10.0
# 25                   Thuin                      0  natural     4.0
# 26     Tournai et Mouscron                      0  natural     5.0
# 27                     Huy                      0  natural     NaN
# 28                   Liège                      0  natural    30.0
# 29                Verviers                      0  natural    15.0
# ...                    ...                    ...      ...     ...
# 44682          La Louvière                      0  natural    26.0
# 44683          La Louvière                      0  natural    31.0
# 44684          La Louvière                      0  natural    26.0
# 44685          La Louvière                      0  natural    24.0
# 44686          La Louvière                      0  natural    31.0
# 44687          La Louvière                      0  natural    28.0
# 44688          La Louvière                      0  natural    19.0
# 44689          La Louvière                      0  natural    27.0
# 44690          La Louvière                      0  natural    35.0
# 44691          La Louvière                      0  natural    21.0
# 44692          La Louvière                      0  natural    32.0
# 44693          La Louvière                      0  natural    30.0
# 44695          La Louvière                      0  natural    31.0
# 44696          La Louvière                      0  natural    27.0
# 44697          La Louvière                      0  natural    17.0
# 44698          La Louvière                      0  natural    18.0
# 44699          La Louvière                      0  natural    26.0
# 44700          La Louvière                      0  natural    29.0
# 44701          La Louvière                      0  natural    25.0
# 44702          La Louvière                      0  natural    22.0
# 44703          La Louvière                      0  natural    28.0
# 44704          La Louvière                      0  natural    23.0
# 44705          La Louvière                      0  natural    22.0
# 44706          La Louvière                      0  natural    29.0
# 44707          La Louvière                      0  natural    39.0
# 44708          La Louvière                      0  natural    26.0
# 44709          La Louvière                      0  natural    26.0
# 44710          La Louvière                      0  natural    24.0
# 44711          La Louvière                      0  natural    37.0
# 44712          La Louvière                      0  natural    27.0
#
# [43081 rows x 10 columns]

# %%
#Extracting Season Feature
data['season']=np.ceil(data.WEEK/13).astype(int)
data.head()
#Extract %Mortality
data['percentage_death']=data.N_MASK/data.population_t
data.head()
# Out:
#    YEAR  ARRON  WEEK  population_t YEAR_WEEK  Nom_arrondissement  \
# 0  2000  11000     1      932103.0  2000-001           Antwerpen
# 1  2000  12000     1      305670.0  2000-001            Mechelen
# 2  2000  13000     1      406199.0  2000-001            Turnhout
# 3  2000  21000     1      959318.0  2000-001  Bruxelles-Capitale
# 4  2000  23000     1      558220.0  2000-001        Hal-Vilvorde
#
#    heatwave_week_boolean    COD_y  N_MASK  season  percentage_death
# 0                      0  natural    31.0       1          0.000033
# 1                      0  natural    10.0       1          0.000033
# 2                      0  natural    14.0       1          0.000034
# 3                      0  natural    43.0       1          0.000045
# 4                      0  natural    14.0       1          0.000025

# %%
np.unique(data['ARRON']).shape
# Out:
# (44,)

# %%
data.prop=data
plot=data.boxplot(column='N_MASK',by='heatwave_week_boolean')
# Out:
# C:\Users\baris\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
data.groupby('heatwave_week_boolean')['N_MASK'].describe()
# Out:
#                          count       mean        std  min   25%   50%   75%  \
# heatwave_week_boolean
# 0                      42820.0  44.051284  40.136975  4.0  16.0  32.0  57.0
# 1                       1626.0  46.075646  41.053569  4.0  16.0  34.0  61.0
#
#                          max
# heatwave_week_boolean
# 0                      317.0
# 1                      238.0

# %%
data.ARRON.isnull().sum()
# Out:
# 0

# %%
# k-means discritizing arrondismants using coordinates to extract regions
arrondissements_url = 'https://raw.githubusercontent.com/mariobecerra/mda_project/main/data/arrondissements_coords.csv'
arron = pd.read_csv(arrondissements_url)
arron.head()
# Out:
#    NIS_Code Nom_arrondissement        lat       lon
# 0     11000          Antwerpen  51.280681  4.505809
# 1     63000           Verviers  50.464213  6.022070
# 2     13000           Turnhout  51.250094  4.950422
# 3     62000              Liège  50.613433  5.607778
# 4     64000            Waremme  50.662789  5.206501

# %%
arron.plot(x='lat',y='lon',kind='scatter',)

# %%
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.cluster import KMeans
d = KMeans(n_clusters=5)
arron['region']=d.fit(arron[['lat','lon']]).labels_
arron.head()

arron.plot.scatter(x='lat',y='lon',c='region',cmap="plasma", s=50)

# %% [markdown]
# ###

# %%
##making yearly heatwaves plot
number_heat=data.groupby(['YEAR','WEEK'])['heatwave_week_boolean'].sum()
a=number_heat[number_heat>0].to_frame()
heat_years=a.groupby('YEAR')['heatwave_week_boolean'].count()
heat_years
# Out:
# YEAR
# 2000    1
# 2001    1
# 2002    5
# 2003    9
# 2004    5
# 2005    9
# 2006    8
# 2007    6
# 2008    3
# 2009    1
# 2010    3
# 2011    4
# 2012    3
# 2014    4
# 2015    5
# 2016    2
# 2017    5
# 2018    7
# 2019    6
# Name: heatwave_week_boolean, dtype: int64

# %%
heat_years.plot.line(x='YEAR',y='heat_years',xticks=list(range(2000, 2020)),rot=45)

# %%
# !pip freeze > requirements.txt
