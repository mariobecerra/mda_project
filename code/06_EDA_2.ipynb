# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
heat_fr = pd.read_csv('../out/hw_freq_df.csv') # heat wave frequency data
heat_intens = pd.read_csv('../out/hw_int_df.csv') # heat wave intensity data

# %%
heat_fr
# Out:
#     arron  1980  1981  1982  1983  1984  1985  1986  1987  1988  ...  2011  \
# 0   41000     1     0     0     0     2     0     4     0     1  ...     0
# 1   11000     1     0     0     0     2     0     4     0     1  ...     0
# 2   81000     3     0     2     0     2     0     4     0     1  ...     0
# 3   51000     1     0     0     0     2     0     4     0     1  ...     0
# 4   45000     1     0     0     0     2     0     4     0     1  ...     0
# 5   82000     3     0     2     0     2     0     4     0     1  ...     0
# 6   31000     1     0     0     0     2     0     4     0     1  ...     0
# 7   21000     1     0     0     0     2     0     4     0     1  ...     0
# 8   52000     1     0     0     0     2     0     4     0     1  ...     0
# 9   34000     1     0     0     0     2     0     4     0     1  ...     0
# 10  42000     1     0     0     0     2     0     4     0     1  ...     0
# 11  32000     1     0     0     0     2     0     4     0     1  ...     0
# 12  91000     3     0     2     0     2     0     4     0     1  ...     0
# 13  43000     1     0     0     0     2     0     4     0     1  ...     0
# 14  44000     1     0     0     0     2     0     4     0     1  ...     0
# 15  23000     1     0     0     0     2     0     4     0     1  ...     0
# 16  71000     3     0     3     0     3     0     4     0     1  ...     0
# 17  61000     3     0     2     0     2     0     4     0     1  ...     0
# 18  58000     1     0     0     0     2     0     4     0     1  ...     0
# 19  24000     3     0     2     0     2     0     4     0     1  ...     0
# 20  62000     3     0     2     0     2     0     4     0     1  ...     0
# 21  72000     3     0     3     0     3     0     4     0     1  ...     0
# 22  83000     3     0     2     0     2     0     4     0     1  ...     0
# 23  12000     1     0     0     0     2     0     4     0     1  ...     0
# 24  53000     1     0     0     0     2     0     4     0     1  ...     0
# 25  54000     1     0     0     0     2     0     4     0     1  ...     0
# 26  92000     3     0     2     0     2     0     4     0     1  ...     0
# 27  84000     3     0     2     0     2     0     4     0     1  ...     0
# 28  25000     1     0     0     0     2     0     4     0     1  ...     0
# 29  35000     1     0     0     0     2     0     4     0     1  ...     0
# 30  93000     1     0     0     0     2     0     4     0     1  ...     0
# 31  36000     1     0     0     0     2     0     4     0     1  ...     0
# 32  46000     1     0     0     0     2     0     4     0     1  ...     0
# 33  55000     1     0     0     0     2     0     4     0     1  ...     0
# 34  56000     1     0     0     0     2     0     4     0     1  ...     0
# 35  37000     1     0     0     0     2     0     4     0     1  ...     0
# 36  73000     3     0     2     0     2     0     4     0     1  ...     0
# 37  57000     1     0     0     0     2     0     4     0     1  ...     0
# 38  13000     3     0     2     0     2     0     4     0     1  ...     0
# 39  63000     3     0     2     0     2     0     4     0     1  ...     0
# 40  38000     1     0     0     0     2     0     4     0     1  ...     0
# 41  85000     3     0     2     0     2     0     4     0     1  ...     0
# 42  64000     3     0     2     0     2     0     4     0     1  ...     0
# 43  33000     1     0     0     0     2     0     4     0     1  ...     0
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0      1     3     0     1     1     1     1     3     5
# 1      1     3     0     1     1     1     1     3     5
# 2      1     0     2     2     2     0     4     2     5
# 3      1     0     1     1     1     0     2     2     5
# 4      1     3     0     1     1     1     1     3     5
# 5      1     0     2     2     2     0     4     2     5
# 6      1     3     0     1     1     1     1     3     5
# 7      1     3     0     1     1     1     1     3     5
# 8      1     0     1     1     1     0     2     2     5
# 9      1     3     0     1     1     1     1     3     5
# 10     1     3     0     1     1     1     1     3     5
# 11     1     3     0     1     1     1     1     3     5
# 12     1     0     1     2     1     0     2     2     5
# 13     1     3     0     1     1     1     1     3     5
# 14     1     3     0     1     1     1     1     3     5
# 15     1     3     0     1     1     1     1     3     5
# 16     1     0     0     2     1     1     5     2     5
# 17     1     0     2     2     2     0     4     2     5
# 18     1     0     1     1     1     0     2     2     5
# 19     1     0     0     2     1     1     2     2     5
# 20     1     0     2     2     2     0     4     2     5
# 21     1     0     0     2     1     1     5     2     5
# 22     1     0     2     2     2     0     4     2     5
# 23     1     3     0     1     1     1     1     3     5
# 24     1     0     1     1     1     0     2     2     5
# 25     1     3     0     1     1     1     1     3     5
# 26     1     0     1     2     1     0     2     2     5
# 27     1     0     2     2     2     0     4     2     5
# 28     1     0     1     1     1     0     2     2     5
# 29     1     3     0     1     1     1     1     3     5
# 30     1     0     1     1     1     0     2     2     5
# 31     1     3     0     1     1     1     1     3     5
# 32     1     3     0     1     1     1     1     3     5
# 33     1     0     1     1     1     0     2     2     5
# 34     1     0     1     1     1     0     2     2     5
# 35     1     3     0     1     1     1     1     3     5
# 36     1     0     2     2     2     0     4     2     5
# 37     1     0     1     1     1     0     2     2     5
# 38     1     0     0     2     1     1     2     2     5
# 39     1     0     2     2     2     0     4     2     5
# 40     1     3     0     1     1     1     1     3     5
# 41     1     0     2     2     2     0     4     2     5
# 42     1     0     2     2     2     0     4     2     5
# 43     1     3     0     1     1     1     1     3     5
#
# [44 rows x 42 columns]

# %% [markdown]
# Create a dataframe for heat wave frequency plot

# %%
Brussels=heat_fr.loc[7].values[1:].tolist() # frequency counts every year for Brussels
Leuven=heat_fr.loc[19].values[1:].tolist() # frequency counts every year for Leuven
years = heat_fr.columns.values[1:].tolist()

hw_freq_Bru = pd.DataFrame()
hw_freq_Bru['Leuven'] = Leuven
hw_freq_Bru['Brussels'] = Brussels
hw_freq_Bru.index=years
hw_freq_Bru.head()
# Out:
#       Leuven  Brussels
# 1980       3         1
# 1981       0         0
# 1982       2         0
# 1983       0         0
# 1984       2         2

# %% [markdown]
# Plot the heat frequencies in Brussels and Leuven

# %%
fig, ax = plt.subplots(1, 1)
ax.set(title = "Heat waves frequency in Brussels (NIS code 21000) and Leuven (NIS code 24000)", 
       ylabel = "Number of heat waves per year")
hw_freq_Bru.plot(ax=ax, figsize=(10,5), legend= "True")
# Out:
# <AxesSubplot:title={'center':'Heat waves frequency in Brussels (NIS code 21000) and Leuven (NIS code 24000)'}, ylabel='Number of heat waves per year'>

# %% [markdown]
# Create a dataframe for heat intensity plot

# %%
Brussels_int=heat_intens.loc[7].values[1:].tolist() # intensity every year for Brussels
Leuven_int=heat_intens.loc[19].values[1:].tolist() # intensity counts every year for Leuven
years = heat_intens.columns.values[1:].tolist()

hw_int_Bru = pd.DataFrame()
hw_int_Bru['Leuven'] = Leuven_int
hw_int_Bru['Brussels'] = Brussels_int
hw_int_Bru.index=years
hw_int_Bru.head()
# Out:
#       Leuven  Brussels
# 1980   2.675     3.875
# 1981   0.000     0.000
# 1982   0.650     0.000
# 1983   0.000     0.000
# 1984   1.550     1.350

# %% [markdown]
# Plot the heat wave intensities in Brussels and surroundings

# %% [markdown]
# Brussels (potential heat island, NIS code 21000) and Halle-Vilvoorde (surrounding area, NIS code 23000) have the same data for some reason. So Brussels and Leuven (next closest arrondisement. NIS code 24000) are taken for checking is there a heat island effect.

# %%
fig, ax = plt.subplots(1, 1)
ax.set(title = "Heat waves intensity in Brussels (NIS code 21000) and Leuven (NIS code 24000)", 
       ylabel = "Intensity of heat waves (°C)")
hw_int_Bru.plot(ax=ax, figsize=(10,5), legend= "True")
# Out:
# <AxesSubplot:title={'center':'Heat waves intensity in Brussels (NIS code 21000) and Leuven (NIS code 24000)'}, ylabel='Intensity of heat waves (°C)'>
